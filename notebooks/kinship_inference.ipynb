# %%
import pandas as pd

# %%
cd /mnt/data_sata_2t/downloads/test
# Out:
# /mnt/data_sata_2t/downloads/test

# %%
# %%bash
#
# wget -c http://people.virginia.edu/~wc9c/KING/Linux-king.tar.gz
# mv Linux-king.tar.gz ~/biosoftwares
# tar zxvf ~/biosoftwares/Linux-king.tar.gz
# Out:
# --2019-03-20 10:36:59--  http://people.virginia.edu/~wc9c/KING/Linux-king.tar.gz
# Resolving people.virginia.edu (people.virginia.edu)... 128.143.22.180
# Connecting to people.virginia.edu (people.virginia.edu)|128.143.22.180|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 799931 (781K) [application/x-gzip]
# Saving to: ‘Linux-king.tar.gz’
#
#      0K .......... .......... .......... .......... ..........  6% 73.8K 10s
#     50K .......... .......... .......... .......... .......... 12%  111K 8s
#    100K .......... .......... .......... .......... .......... 19%  221K 6s
#    150K .......... .......... .......... .......... .......... 25%  112K 5s
#    200K .......... .......... .......... .......... .......... 32%  113K 5s
#    250K .......... .......... .......... .......... .......... 38%  222K 4s
#    300K .......... .......... .......... .......... .......... 44%  113K 4s
#    350K .......... .......... .......... .......... .......... 51%  114K 3s
# ...

# %%
# %%bash
#
# vcftools --vcf trios.vcf --relatedness2 --out trios.vcftools
# Out:
# VCFtools - 0.1.15
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--vcf trios.vcf
# 	--out trios.vcftools
# 	--relatedness2
#
# After filtering, kept 3 out of 3 Individuals
# Outputting Individual Relatedness
# After filtering, kept 48642 out of a possible 48642 Sites
# Run Time = 0.00 seconds

# %%
pd.read_table('trios.vcftools.relatedness2')
# Out:
#         INDV1       INDV2  N_AaAa  N_AAaa  N1_Aa  N2_Aa  RELATEDNESS_PHI
# 0  HY18119189  HY18119189   22851       0  22851  22851         0.500000
# 1  HY18119189  HY18119190   12615     177  22851  22645         0.269496
# 2  HY18119189  HY18119191   13057     181  22851  22969         0.277062
# 3  HY18119190  HY18119189   12615     177  22645  22851         0.269496
# 4  HY18119190  HY18119190   22645       0  22645  22645         0.500000
# 5  HY18119190  HY18119191    9819    3368  22645  22969         0.067589
# 6  HY18119191  HY18119189   13057     181  22969  22851         0.277062
# 7  HY18119191  HY18119190    9819    3368  22969  22645         0.067589
# 8  HY18119191  HY18119191   22969       0  22969  22969         0.500000

# %%
# %%bash
# plink2 --vcf trios.vcf --make-bed --out trios
# ~/biosoftwares/king -b trios.bed --kinship --autoQC --prefix trios.king
# Out:
# PLINK v1.90p 64-bit (25 Mar 2016)          https://www.cog-genomics.org/plink2
# (C) 2005-2016 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to trios.log.
# Options in effect:
#   --make-bed
#   --out trios
#   --vcf trios.vcf
#
# 32122 MB RAM detected; reserving 16061 MB for main workspace.
# --vcf: trios-temporary.bed + trios-temporary.bim + trios-temporary.fam written.
# 48642 variants loaded from .bim file.
# 3 people (0 males, 0 females, 3 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to trios.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 3 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.997217.
# 48642 variants and 3 people pass filters and QC.
# ...

# %%
pd.read_table('trios.king.kin0')
# Out:
#          FID1         ID1        FID2         ID2  N_SNP  HetHet    IBS0  \
# 0  HY18119189  HY18119189  HY18119190  HY18119190  47444  0.2637  0.0029
# 1  HY18119189  HY18119189  HY18119191  HY18119191  47439  0.2704  0.0037
# 2  HY18119190  HY18119190  HY18119191  HY18119191  47435  0.2048  0.0674
#
#    Kinship
# 0   0.2727
# 1   0.2772
# 2   0.0731

# %%
# %%bash
#
# ~/biosoftwares/king -b trios.bed --ibdseg
# ~/biosoftwares/king -b trios.bed --ibdseg --rplot --prefix trios.king
# Out:
# KING 2.1.8 - (c) 2010-2019 Wei-Min Chen
#
# The following parameters are in effect:
#                    Binary File :       trios.bed (-bname)
#
# Additional Options
#          Close Relative Inference : --related, --duplicate
#    Pairwise Relatedness Inference : --kinship, --ibdseg [ON], --ibs, --homog
#               Inference Parameter : --degree
#          Relationship Application : --unrelated, --cluster, --build
#                         QC Report : --bysample, --bySNP, --roh, --autoQC
#                      QC Parameter : --callrateN, --callrateM
#              Population Structure : --pca, --mds
#               Structure Parameter : --projection
#               Disease Association : --tdt
#    Quantitative Trait Association : --mtscore
#                 Association Model : --trait [], --covariate []
#             Association Parameter : --invnorm, --maxP
#                Genetic Risk Score : --risk, --model [], --prevalence, --noflip
# ...

# %%
from IPython.display import IFrame
IFrame("./trios.king_ibd1vsibd2.pdf", width=600, height=300)
#IFrame("./trios.king_gender_autoplot.pdf", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="./trios.king_ibd1vsibd2.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %%bash
#
# ~/biosoftwares/king -b trios.bed --fam trios.fam --bim trios.bim --related --prefix trios.king
# Out:
# KING 2.1.8 - (c) 2010-2019 Wei-Min Chen
#
# The following parameters are in effect:
#                    Binary File :       trios.bed (-bname)
#
# Additional Options
#          Close Relative Inference : --related [ON], --duplicate
#    Pairwise Relatedness Inference : --kinship, --ibdseg, --ibs, --homog
#               Inference Parameter : --degree
#          Relationship Application : --unrelated, --cluster, --build
#                         QC Report : --bysample, --bySNP, --roh, --autoQC
#                      QC Parameter : --callrateN, --callrateM
#              Population Structure : --pca, --mds
#               Structure Parameter : --projection
#               Disease Association : --tdt
#    Quantitative Trait Association : --mtscore
#                 Association Model : --trait [], --covariate []
#             Association Parameter : --invnorm, --maxP
#                Genetic Risk Score : --risk, --model [], --prevalence, --noflip
# ...
