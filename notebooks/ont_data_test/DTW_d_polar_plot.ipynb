# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


# Fixing random state for reproducibility
np.random.seed(19680801)

# Compute areas and colors
N = len(d)
r = 2 * np.random.rand(N)
t = 2 * np.pi * np.random.rand(N)
area = 500 * d
colors = theta

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='polar')
c = ax.scatter(t, d, s=area,c=d, cmap='jet')

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='polar')
c = ax.scatter(t, d, s=area,c=d, cmap='Paired')

# %%
import pandas as pd

# %%
df = pd.read_table('~/Downloads/heat.txt')

# %%
df.plot.hist(bins=np.linspace(0,2,80), density=1);

# %%
d = np.array(list(df.values)*20)

# %%
a = np.arange(0, 2484)

# %%
df.values
# Out:
# array([[112.6753052 ],
#        [  0.        ],
#        [  3.79553668],
#        ...,
#        [ 94.92612556],
#        [  6.6128485 ],
#        [101.03999714]])

# %%
a[:, np.newaxis]
# Out:
# array([[   0],
#        [   1],
#        [   2],
#        ...,
#        [2481],
#        [2482],
#        [2483]])

# %%
len(d)
# Out:
# 4869

# %%
len(t)
# Out:
# 4869

# %%
len(df.values)
# Out:
# 209
